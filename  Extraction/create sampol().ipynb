# %%
import pandas as pd

# %%
df=pd.read_csv('players_20.csv')

# %%
df.set_index('short_name', inplace=True)

# %%
df=df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
## # extract 10 random elements from the "nationality" column
df['club'].sample(10, random_state=99)
# Out:
# short_name
# R. Alvarado                 Cruz Azul
# Qiao Wei                  Shenzhen FC
# E. Paredes                  Colo-Colo
# K. Stoyanov                  Bulgaria
# M. Chudý                Górnik Zabrze
# D. Sundaram                     India
# R. Gagliardini                  Inter
# G. Debeljuh           FC Hermannstadt
# Kim Seung Yong      Incheon United FC
# M. Hansen                 SønderjyskE
# C. Bishop          Accrington Stanley
# J. Longridge            Bradford City
# Pascoal Muscato                Santos
# N. Landgraf             Hallescher FC
# R. Wikström              IFK Göteborg
# L. Agbenyenu             RCD Mallorca
# J. Rengifo             Deportivo Cali
# J. Ramírez          Atlético Nacional
# R. Wallace             Fleetwood Town
# D. Louicius                  Hobro IK
# Name: club, dtype: object

# %%
## extract a random 20% sample of the dataframe
df.sample(frac=0.3, random_state=99)
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# R. Alvarado                Roberto Alvarado   20  1998-09-07        176
# Qiao Wei                           Wei Qiao   31  1987-07-20        187
# E. Paredes                  Esteban Paredes   38  1980-08-01        178
# K. Stoyanov                   Krum Stoyanov   27  1991-08-01        177
# M. Chudý                       Martin Chudý   30  1989-04-23        187
# ...                                     ...  ...         ...        ...
# P. Almqvist                 Pontus Almqvist   19  1999-07-10        178
# D. Berchtold                Diego Berchtold   23  1996-05-27        193
# D. Biseswar                  Diego Biseswar   31  1988-03-08        176
# T. Leibold                      Tim Leibold   25  1993-11-30        174
# G. Cabral     Gustavo Daniel Cabral Cáceres   33  1985-10-14        184
#
#               weight_kg  nationality            club
# short_name
# ...

# %%
## feac=2 means 200% or double the data 
## If frac > 1, you must set replace=True other other wise gives error

df.sample(frac=2, replace=True, random_state=99)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# M. Hauptmeijer               Mike Hauptmeijer   22  1997-03-18        191
# A. Mosquera                   Andrés Mosquera   29  1990-02-20        182
# V. Thill                        Vincent Thill   19  2000-02-04        172
# D. Bouanga                      Denis Bouanga   24  1994-11-11        180
# S. Al Selouli                 Saad Al Selouli   21  1998-05-25        168
# ...                                       ...  ...         ...        ...
# M. Connor                      Matthew Connor   22  1997-04-08        192
# J. Northcott                 Jordan Northcott   17  2002-02-09        162
# A. Bodzek                         Adam Bodzek   33  1985-09-07        184
# J. Adebayo-Smith         Jordan Adebayo-Smith   18  2001-01-11        181
# F. Mac Allister   Francis Manuel Mac Allister   23  1995-10-30        176
#
# ...
