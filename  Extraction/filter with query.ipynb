# %%
import pandas as pd

# %%
df=pd.read_csv('players_20.csv')
df.head(3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# ...

# %%
df.set_index("short_name", inplace=True)

# %%
df=df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]
df.head(3)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain

# %% [markdown]
# # Query()

# %%
## find player age> 40
df.query("age>40")
# Out:
#                                        long_name  age         dob  height_cm  \
# short_name
# G. Buffon                       Gianluigi Buffon   41  1978-01-28        192
# Hilton                  Vitorino Hilton da Silva   41  1977-09-13        180
# C. Lucchetti            Cristian David Lucchetti   41  1978-06-26        182
# F. Kippe                             Frode Kippe   41  1978-01-17        194
# C. Muñoz         Cristian Fernando Muñoz Hoffman   42  1977-07-01        177
# H. Sulaimani  Hussein Omar Abdul Ghani Sulaimani   42  1977-01-21        173
#
#               weight_kg   nationality                          club
# short_name
# G. Buffon            92         Italy                      Juventus
# Hilton               78        Brazil               Montpellier HSC
# C. Lucchetti         69     Argentina              Atlético Tucumán
# F. Kippe             97        Norway                 Lillestrøm SK
# ...

# %%
#the equivalent boolean slicing 
# we can do this with query only
df[df['age']>40]
# Out:
#                                        long_name  age         dob  height_cm  \
# short_name
# G. Buffon                       Gianluigi Buffon   41  1978-01-28        192
# Hilton                  Vitorino Hilton da Silva   41  1977-09-13        180
# C. Lucchetti            Cristian David Lucchetti   41  1978-06-26        182
# F. Kippe                             Frode Kippe   41  1978-01-17        194
# C. Muñoz         Cristian Fernando Muñoz Hoffman   42  1977-07-01        177
# H. Sulaimani  Hussein Omar Abdul Ghani Sulaimani   42  1977-01-21        173
#
#               weight_kg   nationality                          club
# short_name
# G. Buffon            92         Italy                      Juventus
# Hilton               78        Brazil               Montpellier HSC
# C. Lucchetti         69     Argentina              Atlético Tucumán
# F. Kippe             97        Norway                 Lillestrøm SK
# ...

# %%
## df[(df['age']>34) & (df['nationality']=='Italy')]
df.query("age>35 and nationality=='Brazil'" )
# Out:
#                                                  long_name  age         dob  \
# short_name
# Naldo                         Ronaldo  Aparecido Rodrigues   36  1982-09-10
# Hilton                            Vitorino Hilton da Silva   41  1977-09-13
# Douglas                            Douglas Renato de Jesus   36  1983-03-09
# Gomes                              Heurelho da Silva Gomes   38  1981-02-15
# Rafael             Rafael  de Andrade Bittencourt Pinheiro   37  1982-03-03
# Cássio                        Cássio Albuquerque dos Anjos   38  1980-08-12
# Bracali                              Rafael Wihby Bracalli   38  1981-05-05
# Adriano Mezavilla               Adriano Sartorio Mezavilla   36  1983-01-14
# Yuri                                 Yuri de Souza Fonseca   36  1982-08-08
# Rafinha                          Rafael Scapini de Almeida   37  1982-06-29
#
#                    height_cm  weight_kg nationality                     club
# short_name
# ...

# %%
# df[~(df['age']>34)]
df.query("not(age>20)")
# Out:
#                           long_name  age         dob  height_cm  weight_kg  \
# short_name
# K. Mbappé             Kylian Mbappé   20  1998-12-20        178         73
# M. de Ligt         Matthijs de Ligt   19  1999-08-12        189         89
# G. Donnarumma  Gianluigi Donnarumma   20  1999-02-25        196         90
# J. Sancho              Jadon Sancho   19  2000-03-25        180         76
# K. Havertz              Kai Havertz   20  1999-06-11        188         83
# ...                             ...  ...         ...        ...        ...
# Huang Jiahui           Jiahui Huang   18  2000-10-07        183         74
# E. Tweed                 Evan Tweed   20  1999-03-01        180         72
# P. Martin               Paul Martin   20  1999-01-05        188         84
# Zhang Wei                        张威   19  2000-05-16        186         75
# Wang Haijian                    汪海健   18  2000-08-02        185         74
#
# ...

# %%
# convert height to meters and select those with height above 1.8
# df[df['height_cm']/100>1.8]
df.query("(height_cm/100)>1.8")
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# K. De Bruyne                           Kevin De Bruyne   28  1991-06-28
# M. ter Stegen                    Marc-André ter Stegen   27  1992-04-30
# V. van Dijk                            Virgil van Dijk   27  1991-07-08
# ...                                                ...  ...         ...
# P. Martin                                  Paul Martin   20  1999-01-05
# Shao Shuai                                          邵帅   22  1997-03-10
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg          nationality  \
# short_name
# ...

# %%
# # select players that were born after 1990
df.dtypes
# Out:
# long_name      object
# age             int64
# dob            object
# height_cm       int64
# weight_kg       int64
# nationality    object
# club           object
# dtype: object

# %%
# conver "dob" column to datetime type
df['dob']= df['dob'].astype('datetime64[ns]')

# %%
df.head(3)
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27 1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain

# %%
# df[df['dob'].dt.year>1990]
df.query('dob.dt.year>1990')
